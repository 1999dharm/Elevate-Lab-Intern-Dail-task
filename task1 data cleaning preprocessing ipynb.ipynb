# %% [markdown]
# # Task 1: Data Cleaning and Preprocessing

# %% [markdown]
# ## 💡 Objective
#
# Clean and prepare the "Medical Appointment No Show
# dataset by identifying and fixing common data issues
# like missing values, incorrect data types, duplicate entries
# and inconsistent formatting.

# %% [markdown]
# ## 🔧 Tools Used
# - Python
# - Pandas library

# %%
# Steps Performed
# 1. Import Libraries
import pandas as pd

# %%
# 2. Load the Dataset
df = pd.read_csv('Medical appointment No shows.csv')
df
# Out:
#            PatientId  AppointmentID Gender          ScheduledDay  \
# 0       2.987250e+13        5642903      F  2016-04-29T18:38:08Z
# 1       5.589978e+14        5642503      M  2016-04-29T16:08:27Z
# 2       4.262962e+12        5642549      F  2016-04-29T16:19:04Z
# 3       8.679512e+11        5642828      F  2016-04-29T17:29:31Z
# 4       8.841186e+12        5642494      F  2016-04-29T16:07:23Z
# ...              ...            ...    ...                   ...
# 110522  2.572134e+12        5651768      F  2016-05-03T09:15:35Z
# 110523  3.596266e+12        5650093      F  2016-05-03T07:27:33Z
# 110524  1.557663e+13        5630692      F  2016-04-27T16:03:52Z
# 110525  9.213493e+13        5630323      F  2016-04-27T15:09:23Z
# 110526  3.775115e+14        5629448      F  2016-04-27T13:30:56Z
#
#               AppointmentDay  Age      Neighbourhood  Scholarship  \
# 0       2016-04-29T00:00:00Z   62    JARDIM DA PENHA            0
# ...

# %%
# 3. Preview the Data
df.head()       # First 5 rows
# Out:
#       PatientId  AppointmentID Gender          ScheduledDay  \
# 0  2.987250e+13        5642903      F  2016-04-29T18:38:08Z
# 1  5.589978e+14        5642503      M  2016-04-29T16:08:27Z
# 2  4.262962e+12        5642549      F  2016-04-29T16:19:04Z
# 3  8.679512e+11        5642828      F  2016-04-29T17:29:31Z
# 4  8.841186e+12        5642494      F  2016-04-29T16:07:23Z
#
#          AppointmentDay  Age      Neighbourhood  Scholarship  Hipertension  \
# 0  2016-04-29T00:00:00Z   62    JARDIM DA PENHA            0             1
# 1  2016-04-29T00:00:00Z   56    JARDIM DA PENHA            0             0
# 2  2016-04-29T00:00:00Z   62      MATA DA PRAIA            0             0
# 3  2016-04-29T00:00:00Z    8  PONTAL DE CAMBURI            0             0
# 4  2016-04-29T00:00:00Z   56    JARDIM DA PENHA            0             1
#
#    Diabetes  Alcoholism  Handcap  SMS_received No-show
# 0         0           0        0             0      No
# ...

# %%
df.tail()       # Last 5 rows
# Out:
#            PatientId  AppointmentID Gender          ScheduledDay  \
# 110522  2.572134e+12        5651768      F  2016-05-03T09:15:35Z
# 110523  3.596266e+12        5650093      F  2016-05-03T07:27:33Z
# 110524  1.557663e+13        5630692      F  2016-04-27T16:03:52Z
# 110525  9.213493e+13        5630323      F  2016-04-27T15:09:23Z
# 110526  3.775115e+14        5629448      F  2016-04-27T13:30:56Z
#
#               AppointmentDay  Age Neighbourhood  Scholarship  Hipertension  \
# 110522  2016-06-07T00:00:00Z   56   MARIA ORTIZ            0             0
# 110523  2016-06-07T00:00:00Z   51   MARIA ORTIZ            0             0
# 110524  2016-06-07T00:00:00Z   21   MARIA ORTIZ            0             0
# 110525  2016-06-07T00:00:00Z   38   MARIA ORTIZ            0             0
# 110526  2016-06-07T00:00:00Z   54   MARIA ORTIZ            0             0
#
#         Diabetes  Alcoholism  Handcap  SMS_received No-show
# 110522         0           0        0             1      No
# ...

# %%
# 4. Understand the Data


df.info()       # Structure, datatypes, non-null values
df.columns      # Column names
df.describe()   # Statistical summary
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110527 entries, 0 to 110526
# Data columns (total 14 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   PatientId       110527 non-null  float64
#  1   AppointmentID   110527 non-null  int64
#  2   Gender          110527 non-null  object
#  3   ScheduledDay    110527 non-null  object
#  4   AppointmentDay  110527 non-null  object
#  5   Age             110527 non-null  int64
#  6   Neighbourhood   110527 non-null  object
#  7   Scholarship     110527 non-null  int64
#  8   Hipertension    110527 non-null  int64
#  9   Diabetes        110527 non-null  int64
#  10  Alcoholism      110527 non-null  int64
#  11  Handcap         110527 non-null  int64
#  12  SMS_received    110527 non-null  int64
#  13  No-show         110527 non-null  object
# dtypes: float64(1), int64(8), object(5)
# memory usage: 11.8+ MB
#           PatientId  AppointmentID            Age    Scholarship  \
# ...

# %%
# 5. Clean Column Names
df.columns = df.columns.str.lower().str.replace(' ', '_')
df.rename(columns={'handcap': 'handicap'}, inplace=True)
df
# Out:
#            patientid  appointmentid gender          scheduledday  \
# 0       2.987250e+13        5642903      F  2016-04-29T18:38:08Z
# 1       5.589978e+14        5642503      M  2016-04-29T16:08:27Z
# 2       4.262962e+12        5642549      F  2016-04-29T16:19:04Z
# 3       8.679512e+11        5642828      F  2016-04-29T17:29:31Z
# 4       8.841186e+12        5642494      F  2016-04-29T16:07:23Z
# ...              ...            ...    ...                   ...
# 110522  2.572134e+12        5651768      F  2016-05-03T09:15:35Z
# 110523  3.596266e+12        5650093      F  2016-05-03T07:27:33Z
# 110524  1.557663e+13        5630692      F  2016-04-27T16:03:52Z
# 110525  9.213493e+13        5630323      F  2016-04-27T15:09:23Z
# 110526  3.775115e+14        5629448      F  2016-04-27T13:30:56Z
#
#               appointmentday  age      neighbourhood  scholarship  \
# 0       2016-04-29T00:00:00Z   62    JARDIM DA PENHA            0
# ...

# %%
# 6. Standardize Categorical Values
df['gender'] = df['gender'].str.upper()
df['no_show'] = df['no-show'].map({'No': 0, 'Yes': 1})

# %%
# 7. Remove Duplicate Rows
df.drop_duplicates(inplace=True)

# %%
# 8. Convert Data Types
df['patientid'] = df['patientid'].astype(int)

# %%
# 9. Handle Date Columns
df['scheduledday'] = pd.to_datetime(df['scheduledday'], utc=True).dt.tz_localize(None)
df['appointmentday'] = pd.to_datetime(df['appointmentday'], utc=True).dt.tz_localize(None)

# %%
# 10. Split Date and Time
df['appointment_date'] = df['appointmentday'].dt.date
df['appointment_time'] = df['appointmentday'].dt.time

# %%
df.head(40)
# Out:
#      patientid  appointmentid gender        scheduledday appointmentday  age  \
# 0  -2147483648        5642903      F 2016-04-29 18:38:08     2016-04-29   62
# 1  -2147483648        5642503      M 2016-04-29 16:08:27     2016-04-29   56
# 2  -2147483648        5642549      F 2016-04-29 16:19:04     2016-04-29   62
# 3  -2147483648        5642828      F 2016-04-29 17:29:31     2016-04-29    8
# 4  -2147483648        5642494      F 2016-04-29 16:07:23     2016-04-29   56
# 5  -2147483648        5626772      F 2016-04-27 08:36:51     2016-04-29   76
# 6  -2147483648        5630279      F 2016-04-27 15:05:12     2016-04-29   23
# 7  -2147483648        5630575      F 2016-04-27 15:39:58     2016-04-29   39
# 8  -2147483648        5638447      F 2016-04-29 08:02:16     2016-04-29   21
# 9  -2147483648        5629123      F 2016-04-27 12:48:25     2016-04-29   19
# 10 -2147483648        5630213      F 2016-04-27 14:58:11     2016-04-29   30
# ...

# %% [markdown]
# <!-- Final Result
# Column names standardized
# Gender and No-show values cleaned
# Duplicate rows removed
# Data types corrected
# Dates parsed and split into date and time -->

# %%
# Final Result

# Column names standardized

# Gender and No-show values cleaned

# Duplicate rows removed

# Data types corrected

# Dates parsed and split into date and time
